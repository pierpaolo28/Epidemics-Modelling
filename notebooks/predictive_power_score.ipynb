# %% [markdown]
# # Predictive Power Score

# %%
import ppscore as pps
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import seaborn as sns

# %%
Fs = 2500
f = 5
sample = 1000
x = np.arange(sample)
y = np.cos(2 * np.pi * f * x / Fs)
y = [i+random.uniform(1.5, 2) for i in y]
#plt.scatter(x, y)
h = sns.jointplot(x=x, y=y)
h.set_axis_labels('X', 'Y', fontsize=25)
h.fig.suptitle("Noisy Cosine Function", y=1.01, fontsize=25)
h.fig.set_size_inches(10,8)
plt.savefig("pps_ex.svg", format="svg", dpi=200, bbox_inches='tight')

# %%
np.corrcoef(x, y)
# Out:
# array([[ 1.        , -0.00384369],
#        [-0.00384369,  1.        ]])

# %%
d = {'x': x, 'y': y}
df = pd.DataFrame(data=d)
pps.score(df, "x", "y")
# Out:
# {'x': 'x',
#  'y': 'y',
#  'task': 'regression',
#  'ppscore': 0.7375683861765752,
#  'metric': 'mean absolute error',
#  'baseline_score': 0.6416825933307477,
#  'model_score': 0.16839779853018852,
#  'model': DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')}

# %%
pps.matrix(df)
# Out:
#           x  y
# x  1.000000  0
# y  0.737568  1
